# %%
import os, shutil

path = "D:\\BaiduNetdiskDownload\\luck\\"
path2 = "D:\\BaiduNetdiskDownload\\luck\\p"

files = os.listdir(path)

n = 1
for i in files:
    fs = os.listdir(path + i)
    for j in fs:
        oldname = path + i + '\\' + j
       
        newname = path2 + str(n) +"." + j[-3:]
        n=n+1
        print(newname)
        os.rename(oldname,newname)
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# d:\Study\Python\PyScripts\rename.ipynb Cell 1 in <module>
#       <a href='vscode-notebook-cell:/d%3A/Study/Python/PyScripts/rename.ipynb#W0sZmlsZQ%3D%3D?line=7'>8</a> n = 1
#       <a href='vscode-notebook-cell:/d%3A/Study/Python/PyScripts/rename.ipynb#W0sZmlsZQ%3D%3D?line=8'>9</a> for i in files:
# ---> <a href='vscode-notebook-cell:/d%3A/Study/Python/PyScripts/rename.ipynb#W0sZmlsZQ%3D%3D?line=9'>10</a>     fs = os.listdir(path + i)
#      <a href='vscode-notebook-cell:/d%3A/Study/Python/PyScripts/rename.ipynb#W0sZmlsZQ%3D%3D?line=10'>11</a>     for j in fs:
#      <a href='vscode-notebook-cell:/d%3A/Study/Python/PyScripts/rename.ipynb#W0sZmlsZQ%3D%3D?line=11'>12</a>         oldname = path + i + '\\' + j
#
# NotADirectoryError: [WinError 267] 目录名称无效。: 'D:\\BaiduNetdiskDownload\\luck\\118.jpg'

# %%
import os, shutil

path = "D:\\BaiduNetdiskDownload\\luck\\"
path2 = "D:\\BaiduNetdiskDownload\\luck\\"

files = os.listdir(path)

n = 1
for i in files:
    oldname = path + i
    newname = path2 + str(n) +"." + i[-3:]
    n=n+1
    print(newname)
    os.rename(oldname,newname)
# Out:
# D:\BaiduNetdiskDownload\luck\1.jpg
# D:\BaiduNetdiskDownload\luck\2.png
# D:\BaiduNetdiskDownload\luck\3.jpg
# D:\BaiduNetdiskDownload\luck\4.png
# D:\BaiduNetdiskDownload\luck\5.png
# D:\BaiduNetdiskDownload\luck\6.png
# D:\BaiduNetdiskDownload\luck\7.png
# D:\BaiduNetdiskDownload\luck\8.png
# D:\BaiduNetdiskDownload\luck\9.png
# D:\BaiduNetdiskDownload\luck\10.png
# D:\BaiduNetdiskDownload\luck\11.jpg
# D:\BaiduNetdiskDownload\luck\12.png
# D:\BaiduNetdiskDownload\luck\13.png
# D:\BaiduNetdiskDownload\luck\14.png
# D:\BaiduNetdiskDownload\luck\15.png
# D:\BaiduNetdiskDownload\luck\16.png
# D:\BaiduNetdiskDownload\luck\17.png
# D:\BaiduNetdiskDownload\luck\18.png
# D:\BaiduNetdiskDownload\luck\19.png
# D:\BaiduNetdiskDownload\luck\20.png
# D:\BaiduNetdiskDownload\luck\21.png
# D:\BaiduNetdiskDownload\luck\22.png
# D:\BaiduNetdiskDownload\luck\23.png
# D:\BaiduNetdiskDownload\luck\24.png
# D:\BaiduNetdiskDownload\luck\25.png
# D:\BaiduNetdiskDownload\luck\26.png
# ...
